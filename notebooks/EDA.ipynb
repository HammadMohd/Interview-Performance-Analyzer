# %%
import pandas as pd

# %%
df = pd.read_csv('data/features/merged_features.csv')

# %%
df.shape
# Out:
# (2011, 70)

# %%
df.head()
# Out:
#    id     file_name duration_label  question_id            question  openness  \
# 0   1  vid_0001.mp4           long            1  Introduce yourself -0.653086
# 1   2  vid_0002.mp4          short            1  Introduce yourself -0.007390
# 2   3  vid_0003.mp4         medium            1  Introduce yourself  0.221345
# 3   4  vid_0004.mp4         medium            1  Introduce yourself  1.176797
# 4   5  vid_0005.mp4           long            1  Introduce yourself -0.803683
#
#    conscientiousness  extraversion  agreeableness  neuroticism  ...  \
# 0          -0.048688     -0.691034      -0.292822     0.189642  ...
# 1           0.128426     -0.124832      -0.149889     0.087769  ...
# 2           0.280619      0.246076       0.379458    -0.187037  ...
# 3           0.763668      1.309153       1.305436    -0.179641  ...
# 4          -0.548680     -0.777085      -0.748372     0.018259  ...
#
#    nose_shoulder_dist_mean  nose_shoulder_dist_var  hand_speed_mean  \
# ...

# %%
df.sample(5)
# Out:
#         id     file_name duration_label  question_id  \
# 1306  1307  vid_1307.mp4         medium           45
# 1830  1831  vid_1831.mp4         medium           69
# 890    891  vid_0891.mp4           long           27
# 786    787  vid_0787.mp4          short           24
# 587    588  vid_0588.mp4           long           18
#
#                                                question  openness  \
# 1306  Can you give an example of a situation where y...  0.059809
# 1830  Can you give an example of a time when you fac... -1.524332
# 890   Are you open to take risks? or Do you like exp... -0.439697
# 786                               What makes you angry?  0.866166
# 587               How do you handle stress and anxiety? -0.934918
#
#       conscientiousness  extraversion  agreeableness  neuroticism  ...  \
# 1306           0.888690      0.008404       1.376870    -0.543571  ...
# 1830          -0.116997     -1.139953      -0.672891    -0.097266  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 70 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            2011 non-null   int64
#  1   file_name                     2011 non-null   str
#  2   duration_label                2011 non-null   str
#  3   question_id                   2011 non-null   int64
#  4   question                      2011 non-null   str
#  5   openness                      2011 non-null   float64
#  6   conscientiousness             2011 non-null   float64
#  7   extraversion                  2011 non-null   float64
#  8   agreeableness                 2011 non-null   float64
#  9   neuroticism                   2011 non-null   float64
#  10  overall_personality           2011 non-null   float64
#  11  interview_score               2011 non-null   float64
#  12  Duration_Sec                  2011 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# id                     0
# file_name              0
# duration_label         0
# question_id            0
# question               0
#                       ..
# core_speed_mean        0
# posture_shift_count    0
# engagement_score       0
# agitation_score        0
# user_no                0
# Length: 70, dtype: int64

# %%
#How does data looks mathematically

df.describe()
# Out:
#                 id  question_id      openness  conscientiousness  \
# count  2011.000000  2011.000000  2.011000e+03       2.011000e+03
# mean   1006.000000    36.407757 -5.858129e-10      -1.810283e-09
# std     580.670015    25.068381  1.126621e+00       8.769595e-01
# min       1.000000     1.000000 -7.799628e+00      -6.928705e+00
# 25%     503.500000    15.000000 -5.492694e-01      -4.483626e-01
# 50%    1006.000000    34.000000  8.590045e-03       4.257322e-02
# 75%    1508.500000    58.000000  5.222476e-01       4.851403e-01
# max    2011.000000    76.000000  9.338849e+00       6.617010e+00
#
#        extraversion  agreeableness   neuroticism  overall_personality  \
# count  2.011000e+03   2.011000e+03  2.011000e+03         2.011000e+03
# mean  -8.733420e-10  -2.707772e-09  5.822762e-10        -4.385845e-09
# std    1.098106e+00   1.200348e+00  4.868924e-01         1.203363e+00
# min   -7.184409e+00  -8.412302e+00 -2.576639e+00        -7.526180e+00
# ...

# %%
#Are there duplicate values ?

df.duplicated().sum
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2006    False
# 2007    False
# 2008    False
# 2009    False
# 2010    False
# Length: 2011, dtype: bool>

# %%
#correlation between columns

df.corr(numeric_only=True)['openness']
# Out:
# id                     7.171259e-04
# question_id           -5.222878e-10
# openness               1.000000e+00
# conscientiousness      5.642605e-01
# extraversion           7.391658e-01
#                            ...
# core_speed_mean        5.588203e-02
# posture_shift_count   -1.613284e-02
# engagement_score      -1.914462e-02
# agitation_score       -1.517808e-02
# user_no               -1.340400e-02
# Name: openness, Length: 66, dtype: float64

# %%
import seaborn as sns

# %%
sns.scatterplot(y=df['openness'],x=df['agreeableness'],hue=df['user_no'],style=df['hand_to_face_touches'],size=df['extraversion'])
# Out:
# <Axes: xlabel='agreeableness', ylabel='openness'>

# %%
sns.barplot(y=df['openness'],x=df['duration_label'])
# Out:
# <Axes: xlabel='duration_label', ylabel='openness'>

# %%
sns.boxplot(x=df['duration_label'],y=df['openness'])
# Out:
# <Axes: xlabel='duration_label', ylabel='openness'>

# %%
sns.distplot(df['openness'])
# Out:
# C:\Users\khuzi\AppData\Local\Temp\ipykernel_2152\3794391011.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['openness'])
# <Axes: xlabel='openness', ylabel='Density'>

# %%
df.head()
# Out:
#    id     file_name duration_label  question_id            question  openness  \
# 0   1  vid_0001.mp4           long            1  Introduce yourself -0.653086
# 1   2  vid_0002.mp4          short            1  Introduce yourself -0.007390
# 2   3  vid_0003.mp4         medium            1  Introduce yourself  0.221345
# 3   4  vid_0004.mp4         medium            1  Introduce yourself  1.176797
# 4   5  vid_0005.mp4           long            1  Introduce yourself -0.803683
#
#    conscientiousness  extraversion  agreeableness  neuroticism  ...  \
# 0          -0.048688     -0.691034      -0.292822     0.189642  ...
# 1           0.128426     -0.124832      -0.149889     0.087769  ...
# 2           0.280619      0.246076       0.379458    -0.187037  ...
# 3           0.763668      1.309153       1.305436    -0.179641  ...
# 4          -0.548680     -0.777085      -0.748372     0.018259  ...
#
#    nose_shoulder_dist_mean  nose_shoulder_dist_var  hand_speed_mean  \
# ...
