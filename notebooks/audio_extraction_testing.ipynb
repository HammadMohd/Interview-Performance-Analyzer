# %%
import torch
import librosa
import whisper

print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

print("Librosa imported successfully")
# Out:
# Torch: 2.13.0+cu126
# CUDA available: True
# GPU: NVIDIA GeForce GTX 1650
# Librosa imported successfully

# %%
import ffmpeg

print("ffmpeg-python imported successsfully")
# Out:
# ffmpeg-python imported successsfully

# %%
import os

audio_output_path = "../data/processed/audio"

os.makedirs(audio_output_path, exist_ok=True)

print("Audio output folder ready:", audio_output_path)
# Out:
# Audio output folder ready: ../data/processed/audio

# %%
from datasets import load_dataset

dataset = load_dataset("AI4A-Lab/RecruitView")

print(dataset)
# Out:
# Resolving data files:   0%|          | 0/2012 [00:00<?, ?it/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'video', 'duration', 'question_id', 'question', 'video_quality', 'user_no', 'openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism', 'overall_personality', 'interview_score', 'answer_score', 'speaking_skills', 'confidence_score', 'facial_expression', 'overall_performance', 'transcript', 'gemini_summary'],
#         num_rows: 2011
#     })
# })

# %%
sample = dataset["train"][0]

print(sample.keys())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 sample = dataset["train"][0]
#       2
#       3 print(sample.keys())
#
# File d:\Audio_Extraction\Interview-Performance-Analyzer\venv\Lib\site-packages\datasets\arrow_dataset.py:3158, in Dataset.__getitem__(self, key)
#    3156     if self._format_type is None or self._format_type not in ("arrow", "pandas", "polars"):
#    3157         return Column(self, key)
# -> 3158 return self._getitem(key)
#
# File d:\Audio_Extraction\Interview-Performance-Analyzer\venv\Lib\site-packages\datasets\arrow_dataset.py:3140, in Dataset._getitem(self, key, **kwargs)
#    3138 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    3139 pa_subtable = query_table(self._data, key, indices=self._indices)
# -> 3140 formatted_output = format_table(
# ...

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'video', 'duration', 'question_id', 'question', 'video_quality', 'user_no', 'openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism', 'overall_personality', 'interview_score', 'answer_score', 'speaking_skills', 'confidence_score', 'facial_expression', 'overall_performance', 'transcript', 'gemini_summary'],
#         num_rows: 2011
#     })
# })

# %%
print(dataset["train"].features)
# Out:
# {'id': Value('string'), 'video': Video(decode=True, stream_index=None, dimension_order='NCHW', num_ffmpeg_threads=1, device='cpu', seek_mode='exact'), 'duration': Value('string'), 'question_id': Value('string'), 'question': Value('string'), 'video_quality': Value('string'), 'user_no': Value('string'), 'openness': Value('float64'), 'conscientiousness': Value('float64'), 'extraversion': Value('float64'), 'agreeableness': Value('float64'), 'neuroticism': Value('float64'), 'overall_personality': Value('float64'), 'interview_score': Value('float64'), 'answer_score': Value('float64'), 'speaking_skills': Value('float64'), 'confidence_score': Value('float64'), 'facial_expression': Value('float64'), 'overall_performance': Value('float64'), 'transcript': Value('string'), 'gemini_summary': Value('string')}

# %%
sample=dataset["train"].select([0])

print(sample)
# Out:
# Dataset({
#     features: ['id', 'video', 'duration', 'question_id', 'question', 'video_quality', 'user_no', 'openness', 'conscientiousness', 'extraversion', 'agreeableness', 'neuroticism', 'overall_personality', 'interview_score', 'answer_score', 'speaking_skills', 'confidence_score', 'facial_expression', 'overall_performance', 'transcript', 'gemini_summary'],
#     num_rows: 1
# })

# %%
print(sample["transcript"])
# Out:
# Column(['[00:01 - 00:11] Hello everyone, this is Mathurima Roy. I am a third year BTech student from Manipal University, Jaipur, currently majoring in CS, Computer Science.\n[00:12 - 00:18] I am a tech enthusiast and I love to explore the domains of artificial intelligence and machine learning.\n[00:18 - 00:30] I also have a sheer interest in exploring the realm of blockchain and its decentralized apps with an interest of playing with softwares.\n[00:30 - 00:41] My hobbies include dancing, reading, I am an avid reader, and also exploring new places, meeting new people, their culture and their heritage.'])

# %%
print(dataset["train"].features["video"])
# Out:
# Video(decode=True, stream_index=None, dimension_order='NCHW', num_ffmpeg_threads=1, device='cpu', seek_mode='exact')

# %%
print(dataset["train"][0]["id"])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(dataset["train"][0]["id"])
#
# File d:\Audio_Extraction\Interview-Performance-Analyzer\venv\Lib\site-packages\datasets\arrow_dataset.py:3158, in Dataset.__getitem__(self, key)
#    3156     if self._format_type is None or self._format_type not in ("arrow", "pandas", "polars"):
#    3157         return Column(self, key)
# -> 3158 return self._getitem(key)
#
# File d:\Audio_Extraction\Interview-Performance-Analyzer\venv\Lib\site-packages\datasets\arrow_dataset.py:3140, in Dataset._getitem(self, key, **kwargs)
#    3138 formatter = get_formatter(format_type, features=self._info.features, **format_kwargs)
#    3139 pa_subtable = query_table(self._data, key, indices=self._indices)
# -> 3140 formatted_output = format_table(
# ...

# %%
import torchcodec
print("torchcodec ok")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torchcodec
#       2 print("torchcodec ok")
#
# File d:\Audio_Extraction\Interview-Performance-Analyzer\venv\Lib\site-packages\torchcodec\__init__.py:10
#       1 # Copyright (c) Meta Platforms, Inc. and affiliates.
#       2 # All rights reserved.
#       3 #
#    (...)      7 # Note: usort wants to put Frame and FrameBatch after decoders and samplers,
#       8 # but that results in circular import.
#       9 from ._frame import AudioSamples, Frame, FrameBatch  # usort:skip # noqa
# ---> 10 from . import decoders, samplers  # noqa
#      12 try:
#      13     # Note that version.py is generated during install.
#      14     from .version import __version__  # noqa: F401
#
# File d:\Audio_Extraction\Interview-Performance-Analyzer\venv\Lib\site-packages\torchcodec\decoders\__init__.py:7
# ...
